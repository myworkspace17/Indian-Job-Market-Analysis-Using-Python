# %% [markdown]
# # Indian Job Market Analysis Using Python

# %% [markdown]
# #  by Hari krishna

# %%
Installing the Python Libraries

# %%
import pandas as pd   # pandas for Data Manipulaton
import numpy as np
import matplotlib.pyplot as plt   # matplotlib and Seaborn for Data visulaization
import seaborn as sns

# %%
Loading  the Data

# %%
df=pd.read_csv(r"C:\Users\hanra\OneDrive\Documents\Python Projects\india_job_market_dataset.csv")

# %%
df
# Out:
#          Job ID             Job Title Company Name Job Location    Job Type  \
# 0          JOB1     Software Engineer       Amazon    Ahmedabad   Full-time
# 1          JOB2   Marketing Executive      Infosys    Ahmedabad  Internship
# 2          JOB3     Financial Analyst     Deloitte       Jaipur    Contract
# 3          JOB4      Business Analyst       Amazon        Delhi   Full-time
# 4          JOB5     Software Engineer      Infosys        Delhi   Full-time
# ...         ...                   ...          ...          ...         ...
# 19995  JOB19996   Marketing Executive     Deloitte         Pune   Full-time
# 19996  JOB19997      Business Analyst    Accenture    Bangalore  Internship
# 19997  JOB19998      Graphic Designer        Wipro       Jaipur   Part-time
# 19998  JOB19999  Sales Representative      Infosys      Kolkata  Internship
# 19999  JOB20000      Business Analyst    Accenture       Mumbai   Part-time
#
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of          Job ID             Job Title Company Name Job Location    Job Type  \
# 0          JOB1     Software Engineer       Amazon    Ahmedabad   Full-time
# 1          JOB2   Marketing Executive      Infosys    Ahmedabad  Internship
# 2          JOB3     Financial Analyst     Deloitte       Jaipur    Contract
# 3          JOB4      Business Analyst       Amazon        Delhi   Full-time
# 4          JOB5     Software Engineer      Infosys        Delhi   Full-time
# ...         ...                   ...          ...          ...         ...
# 19995  JOB19996   Marketing Executive     Deloitte         Pune   Full-time
# 19996  JOB19997      Business Analyst    Accenture    Bangalore  Internship
# 19997  JOB19998      Graphic Designer        Wipro       Jaipur   Part-time
# 19998  JOB19999  Sales Representative      Infosys      Kolkata  Internship
# 19999  JOB20000      Business Analyst    Accenture       Mumbai   Part-time
#
# ...

# %%
df["Job Title"].unique()
# Out:
# array(['Software Engineer', 'Marketing Executive', 'Financial Analyst',
#        'Business Analyst', 'Data Scientist', 'Sales Representative',
#        'Product Manager', 'HR Manager', 'Cyber Security Analyst',
#        'Graphic Designer'], dtype=object)

# %% [markdown]
# # Job Trend Analysis:

# %% [markdown]
# # What is  the Most  in_demand Job roles?

# %%
sns.countplot(x="Job Title",data=df,hue="Job Title")

plt.xticks(rotation=90)
plt.xlabel("Job Title",fontsize=15)
plt.ylabel("Count",fontsize=15)
plt.title("Count Of Demand for  Job Title",fontsize=17,color="green")
plt.show()

# %% [markdown]
# # Which companies are posting the most job openings?

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Get the count of job postings for each company
top_companies = df['Company Name'].value_counts().head(10)  # Get the top 10 companies

# Create a bar plot
plt.figure(figsize=(12, 8))
sns.barplot(x=top_companies.values, y=top_companies.index)

# Set labels and title
plt.xlabel('Number of Job Openings', fontsize=15)
plt.ylabel('Company Name', fontsize=15)
plt.title('Top 10 Companies Posting the Most Job Openings', fontsize=17, color="green")

# Display the plot
plt.show()

# %% [markdown]
# # What is the distribution of job types?

# %%
gb=df.groupby("Job Type").agg({"Job ID":"count"})
print(gb)
plt.pie(gb['Job ID'],labels=gb.index,autopct="%1.2f%%")
plt.show()
# Out:
#             Job ID
# Job Type
# Contract      4823
# Full-time     4981
# Internship    5085
# Part-time     5111

# %% [markdown]
#  # Salary and Experience Analysis:

# %% [markdown]
# # What is the distribution of salary ranges across different job roles?

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create a count plot to visualize the distribution of salary ranges across different job roles
plt.figure(figsize=(14, 8))

# Create the countplot
sns.countplot(
    x='Job Title',  # Job Titles on the x-axis
    data=df,        # Data to plot
    hue='Salary Range',  # Different salary ranges as hues (colors)
    palette='magma'  # Color palette for the plot
)

# Rotate the x-axis labels for better readability
plt.xticks(rotation=90)

# Set plot title and axis labels
plt.title("Distribution of Salary Ranges Across Job Roles", fontsize=17, color='darkred')
plt.xlabel("Job Title", fontsize=14)
plt.ylabel("Number of Job Openings", fontsize=14)

# Adjust layout to avoid clipping the labels and legend
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# # What is the average experience required for different job types?

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x="Job Type", data=df, hue="Job Type", palette="Set2")

#  Customize the plot
plt.xticks(rotation=90)  # Rotate the x-axis labels (job types)
plt.xlabel("Job Type", fontsize=15)
plt.ylabel("Count", fontsize=15)
plt.title("Distribution of Job Types", fontsize=17, color="green")
plt.tight_layout()  # Ensure the plot is properly adjusted

# Show the plot
plt.show()

# %% [markdown]
# # Which salary range has the highest number of job postings?

# %%
Salary_range=df['Salary Range'].unique()
print(Salary_range)
# Out:
# ['5-8 LPA' '20+ LPA' '12-20 LPA' '3-5 LPA' '8-12 LPA']

# %%
df.groupby('Salary Range')['Number of Applicants'].sum().head()
# Out:
# Salary Range
# 12-20 LPA    1034750
# 20+ LPA      1025522
# 3-5 LPA      1034562
# 5-8 LPA      1017017
# 8-12 LPA     1022615
# Name: Number of Applicants, dtype: int64

# %%
salary_applicant_sum = df.groupby('Salary Range')['Number of Applicants'].sum()

# Plot the result as a bar chart
plt.figure(figsize=(12, 6))
salary_applicant_sum.plot(kind='bar', color='lightgreen')

# Add labels and title
plt.xlabel('Salary Range', fontsize=12)
plt.ylabel('Total Number of Applicants', fontsize=12)
plt.title('Total Number of Applicants for Each Salary Range', fontsize=14)

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Show the plot
plt.show()

# %% [markdown]
# # Location Insights:

# %% [markdown]
# # Which cities have the highest number of job opportunities?

# %%
df.groupby('Job Location')['Number of Applicants'].sum().head()
# Out:
# Job Location
# Ahmedabad    526155
# Bangalore    520893
# Chennai      514549
# Delhi        524877
# Hyderabad    526234
# Name: Number of Applicants, dtype: int64

# %%
# Group data by 'Job Location' and sum the 'Number of Applicants' for each location
location_applicant_sum = df.groupby('Job Location')['Number of Applicants'].sum()

# Plot the result as a bar chart
plt.figure(figsize=(12, 6))
location_applicant_sum.plot(kind='bar', color='lightblue')

# Add labels and title
plt.xlabel('Job Location', fontsize=12)
plt.ylabel('Total Number of Applicants', fontsize=12)
plt.title('Total Number of Applicants for Each Job Location', fontsize=14)

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Show the plot
plt.show()

# %% [markdown]
# # What are the most common job types in each location?

# %%
job_types_location=df.groupby('Job Location')['Job Type'].value_counts()
print(job_types_location)
highest_jobtypes_location=job_types_location.head()
print(highest_jobtypes_location)
# Out:
# Job Location  Job Type
# Ahmedabad     Part-time     525
#               Internship    511
#               Full-time     495
#               Contract      488
# Bangalore     Internship    550
#               Part-time     515
#               Contract      481
#               Full-time     477
# Chennai       Part-time     547
#               Full-time     496
#               Internship    489
#               Contract      486
# Delhi         Internship    503
#               Full-time     500
#               Contract      494
#               Part-time     493
# Hyderabad     Full-time     531
#               Internship    527
#               Contract      504
#               Part-time     493
# Jaipur        Internship    521
#               Full-time     509
#               Part-time     508
#               Contract      481
# Kolkata       Full-time     510
#               Part-time     495
#               Internship    483
#               Contract      467
# ...

# %%
# Group by 'Job Location' and 'Job Type' to get the count of job types per location
job_types_location = df.groupby('Job Location')['Job Type'].value_counts()

# Get the top job types for each location
highest_jobtypes_location = job_types_location.head(10)  # top 10 for illustration

# Reset index to make 'Job Location' and 'Job Type' columns
highest_jobtypes_location = highest_jobtypes_location.reset_index(name='Count')

# Visualize the top job types in different locations
plt.figure(figsize=(12, 8))
sns.barplot(x='Count', y='Job Type', hue='Job Location', data=highest_jobtypes_location)

# Add labels and title
plt.xlabel('Number of Job Postings', fontsize=12)
plt.ylabel('Job Type', fontsize=12)
plt.title('Most Common Job Types in Each Location', fontsize=14)
plt.xticks(rotation=45)
plt.legend(title='Job Location', bbox_to_anchor=(1.05, 1), loc='upper left')

# Show the plot
plt.tight_layout()
plt.show()

# %%
# Assuming df is your DataFrame
job_types_location = df.groupby('Job Location')['Job Type'].value_counts().unstack().fillna(0)

# Plotting
plt.figure(figsize=(12, 6))
job_types_location.plot(kind='bar', stacked=True, colormap='viridis', ax=plt.gca())
plt.title('Job Types by Location', fontsize=16)
plt.xlabel('Job Location', fontsize=14)
plt.ylabel('Number of Job Types', fontsize=14)
plt.xticks(rotation=45)
plt.legend(title='Job Type', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Skills and Education Analysis:

# %% [markdown]
# # Which skills are most frequently required in job postings?

# %%
df
# Out:
#          Job ID             Job Title Company Name Job Location    Job Type  \
# 0          JOB1     Software Engineer       Amazon    Ahmedabad   Full-time
# 1          JOB2   Marketing Executive      Infosys    Ahmedabad  Internship
# 2          JOB3     Financial Analyst     Deloitte       Jaipur    Contract
# 3          JOB4      Business Analyst       Amazon        Delhi   Full-time
# 4          JOB5     Software Engineer      Infosys        Delhi   Full-time
# ...         ...                   ...          ...          ...         ...
# 19995  JOB19996   Marketing Executive     Deloitte         Pune   Full-time
# 19996  JOB19997      Business Analyst    Accenture    Bangalore  Internship
# 19997  JOB19998      Graphic Designer        Wipro       Jaipur   Part-time
# 19998  JOB19999  Sales Representative      Infosys      Kolkata  Internship
# 19999  JOB20000      Business Analyst    Accenture       Mumbai   Part-time
#
# ...

# %%
 skill_applicants=df.groupby('Skills Required')['Number of Applicants'].sum() # group the data by skills required and total job applicants
# sort the results in descending order to see which skills have highest number of applicants
sorted_skill_applicants= skill_applicants.sort_values(ascending=False)
# print the sorted applicants result
print(sorted_skill_applicants.head())

# for clear understanding we use data visualization method using matplotlib and seaborn libraries
# Now lets  we visualize   barplot 
plt.figure(figsize=(10, 6))
sns.barplot(x=sorted_skill_applicants.head(10).index, y=sorted_skill_applicants.head(10).values)

plt.xticks(rotation=90)  # Rotate the labels for better readability
plt.xlabel('Skills Required', fontsize=12)
plt.ylabel('Number of Applicants', fontsize=12)
plt.title('Top 10 Skills with the Highest Number of Applicants', fontsize=15)
plt.show()
# Out:
# Skills Required
# Java, UI/UX, React                12255
# SQL, Java, React                  11936
# SQL, React, UI/UX                 11593
# Machine Learning, C++, Python     11564
# Excel, Java, Digital Marketing    11273
# Name: Number of Applicants, dtype: int64

# %% [markdown]
# # What is the correlation between educational qualifications and salary ranges?

# %%
# Group the data by 'Education Requirement' and 'Salary Range' and count the number of job postings
edu_salary_counts = df.groupby(['Education Requirement', 'Salary Range']).size().reset_index(name='Number of Postings')

# Create a pivot table to format the data for visualization
edu_salary_pivot = edu_salary_counts.pivot(index='Education Requirement', columns='Salary Range', values='Number of Postings')

# Plot a heatmap to visualize the correlation between education requirement and salary range
plt.figure(figsize=(12, 8))
sns.heatmap(edu_salary_pivot, annot=True, cmap='Blues', fmt='d', linewidths=0.5)

plt.title('Correlation between Education Requirement and Salary Range', fontsize=16)
plt.xlabel('Salary Range', fontsize=12)
plt.ylabel('Education Requirement', fontsize=12)
plt.xticks(rotation=45)
plt.show()

# %%
# Group the data by 'Education Requirement' and 'Salary Range' and count the number of job postings
edu_salary_counts = df.groupby(['Education Requirement', 'Salary Range']).size().reset_index(name='Number of Postings')

# Create a histogram-like effect using FacetGrid
plt.figure(figsize=(12, 8))
g = sns.FacetGrid(edu_salary_counts, col='Education Requirement', col_wrap=3, height=4)
g.map_dataframe(sns.histplot, x='Salary Range', weights='Number of Postings', bins=len(edu_salary_counts['Salary Range'].unique()), kde=False)
g.set_axis_labels('Salary Range', 'Number of Postings')
g.set_titles(col_template="{col_name}")
g.add_legend()

plt.subplots_adjust(top=0.9)
g.fig.suptitle('Distribution of Job Postings by Education Requirement and Salary Range', fontsize=16)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Which education level is most demanded for different job roles?

# %%
# Group the data by Education and Job Roles 
edu_job_roles=df.groupby('Education Requirement')['Job Title'].size()
print(edu_job_roles)
# Create a countplot to visualize the number of job titles for each education requirement
plt.figure(figsize=(10, 6))
sns.countplot(x='Education Requirement', data=df, order=df['Education Requirement'].value_counts().index)

# Adding labels and title
plt.xlabel('Education Requirement', fontsize=12)
plt.ylabel('Number of Job Titles', fontsize=12)
plt.title('Number of Job Titles for Each Education Requirement', fontsize=16)
plt.xticks(rotation=45)
plt.show()
# Out:
# Education Requirement
# B.Sc      4023
# B.Tech    4014
# M.Tech    3983
# MBA       3986
# PhD       3994
# Name: Job Title, dtype: int64

# %%
# Get the counts of job titles for each education requirement
edu_job_roles = df['Education Requirement'].value_counts()

# Plotting the pie chart
plt.figure(figsize=(8, 8))
plt.pie(edu_job_roles, labels=edu_job_roles.index, autopct='%1.1f%%', startangle=140, colors=plt.cm.Paired.colors)

# Adding title
plt.title('Distribution of Job Titles by Education Requirement', fontsize=16)

# Show the plot
plt.show()

# %%
# Create a contingency table between Education Requirement and Job Title
edu_job_crosstab = pd.crosstab(df['Education Requirement'], df['Job Title'])

# Normalize the table to get percentages
edu_job_crosstab_percentage = edu_job_crosstab.div(edu_job_crosstab.sum(axis=1), axis=0) * 100

# Create a heatmap to visualize the correlation
plt.figure(figsize=(12, 8))
sns.heatmap(edu_job_crosstab_percentage, annot=True, fmt='.1f', cmap='coolwarm', cbar_kws={'label': 'Percentage (%)'})

# Add title
plt.title('Correlation between Education Requirement and Job Titles', fontsize=16)
plt.xlabel('Job Title', fontsize=12)
plt.ylabel('Education Requirement', fontsize=12)

# Show the plot
plt.show()

# %% [markdown]
# # Hiring Timeline:

# %% [markdown]
# # How does the number of job postings vary by month? (Line chart of postings over time)

# %%
df['Posted Date']=pd.to_datetime(df['Posted Date'],errors='coerce')
#Extract Year and Month
df['Month']=df['Posted Date'].dt.to_period('M') 
monthly_postings=df.groupby('Month')['Job Title'].size().reset_index(name='Number of Postings')
#Display the monthly postings
print(monthly_postings)
# Out:
#      Month  Number of Postings
# 0  2024-12                5782
# 1  2025-01               14218

# %%
# Plot the monthly job postings as a line chart
plt.figure(figsize=(12, 6))
plt.plot(monthly_postings['Month'].astype(str), monthly_postings['Number of Postings'], marker='o', color='r')

# Adding labels and title
plt.xlabel('Month')
plt.ylabel('Number of Postings')
plt.title('Number of Job Postings per Month')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.grid(True)

# Display the plot
plt.tight_layout()
plt.show()

# %%
# creating a bar plot for bettter understanding

# %%
# Create a barplot to visualize the number of job postings per month
plt.figure(figsize=(12, 6))
sns.barplot(x=monthly_postings['Month'].astype(str), y=monthly_postings['Number of Postings'], palette='viridis')

# Adding labels and title
plt.xlabel('Month')
plt.ylabel('Number of Postings')
plt.title('Number of Job Postings per Month')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.grid(True)

# Display the plot
plt.tight_layout()
plt.show()
# Out:
# C:\Users\hanra\AppData\Local\Temp\ipykernel_22040\448727895.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=monthly_postings['Month'].astype(str), y=monthly_postings['Number of Postings'], palette='viridis')

# %% [markdown]
# # What is the average duration between job posting and application deadline? (Histogram)

# %%
df
# Out:
#          Job ID             Job Title Company Name Job Location    Job Type  \
# 0          JOB1     Software Engineer       Amazon    Ahmedabad   Full-time
# 1          JOB2   Marketing Executive      Infosys    Ahmedabad  Internship
# 2          JOB3     Financial Analyst     Deloitte       Jaipur    Contract
# 3          JOB4      Business Analyst       Amazon        Delhi   Full-time
# 4          JOB5     Software Engineer      Infosys        Delhi   Full-time
# ...         ...                   ...          ...          ...         ...
# 19995  JOB19996   Marketing Executive     Deloitte         Pune   Full-time
# 19996  JOB19997      Business Analyst    Accenture    Bangalore  Internship
# 19997  JOB19998      Graphic Designer        Wipro       Jaipur   Part-time
# 19998  JOB19999  Sales Representative      Infosys      Kolkata  Internship
# 19999  JOB20000      Business Analyst    Accenture       Mumbai   Part-time
#
# ...

# %%
# Ensure 'Posted Date' and 'Application Deadline' are datetime objects
df['Posted Date'] = pd.to_datetime(df['Posted Date'], errors='coerce')
df['Application Deadline'] = pd.to_datetime(df['Application Deadline'], errors='coerce')

# Calculate the duration between job posting and application deadline
df['Duration (Days)'] = (df['Application Deadline'] - df['Posted Date']).dt.days

# Drop any rows where the duration is NaN (in case of missing or invalid dates)
df = df.dropna(subset=['Duration (Days)'])

# Create a histogram to visualize the distribution of the duration
plt.figure(figsize=(10, 6))
plt.hist(df['Duration (Days)'], bins=30, color='green', edgecolor='black')

# Adding labels and title
plt.xlabel('Duration (Days)')
plt.ylabel('Frequency')
plt.title('Distribution of Duration Between Job Posting and Application Deadline')

# Display the plot
plt.tight_layout()
plt.show()

# %%
# Ensure 'Posted Date' and 'Application Deadline' are datetime objects
df['Posted Date'] = pd.to_datetime(df['Posted Date'], errors='coerce')
df['Application Deadline'] = pd.to_datetime(df['Application Deadline'], errors='coerce')

# Calculate the duration between job posting and application deadline
df['Duration (Days)'] = (df['Application Deadline'] - df['Posted Date']).dt.days

# Drop any rows where the duration is NaN (in case of missing or invalid dates)
df = df.dropna(subset=['Duration (Days)'])

# Create a figure for the plot
plt.figure(figsize=(12, 6))

# Create a histogram with a KDE overlay
sns.histplot(df['Duration (Days)'], bins=30, kde=True, color='skyblue', edgecolor='black', stat='density')

# Adding labels and title
plt.xlabel('Duration (Days)', fontsize=14)
plt.ylabel('Density', fontsize=14)
plt.title('Distribution of Duration Between Job Posting and Application Deadline', fontsize=16)

# Display the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# # Application Trends:

# %% [markdown]
# # Which job portals are attracting the highest number of applicants?

# %%
# Group the data with job portal and Number of Applicants 
job_portal_applicants=df.groupby('Job Portal')['Number of Applicants'].sum()
# display the result of the grouping of job portal and number of appplicants
print(job_portal_applicants.head())
# Out:
# Job Portal
# Indeed        1728195
# LinkedIn      1665690
# Naukri.com    1740581
# Name: Number of Applicants, dtype: int64
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[120], line 8
#       5 # Now plot a bar plot  to visualize the data for better understanding
#       6 # Plotting
#       7 plt.figure(figsize=(12, 6))
# ----> 8 sns.barplot(data=job_portal_applicants, x='Job Portal', y='Number of Applicants', palette='viridis')
#      10 # Adding labels and title
#      11 plt.title('Total Number of Applicants by Job Portal', fontsize=16)
#
# ...

# %%
import matplotlib.pyplot as plt

# Group the data by 'Job Portal' and sum 'Number of Applicants'
job_portal_applicants = df.groupby('Job Portal')['Number of Applicants'].sum()

# Display the result of the grouping
print(job_portal_applicants.head())

# Plotting the bar chart
plt.figure(figsize=(10, 6))
job_portal_applicants.plot(kind='bar', color='skyblue')
plt.title('Number of Applicants by Job Portal')
plt.xlabel('Job Portal')
plt.ylabel('Number of Applicants')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# Job Portal
# Indeed        1728195
# LinkedIn      1665690
# Naukri.com    1740581
# Name: Number of Applicants, dtype: int64

# %%
# Group the data by 'Job Portal' and sum 'Number of Applicants'
job_portal_applicants = df.groupby('Job Portal')['Number of Applicants'].sum()

# Display the result of the grouping
print(job_portal_applicants.head())

# Plotting the pie chart
plt.figure(figsize=(8, 8))
job_portal_applicants.plot(kind='pie', autopct='%1.1f%%', startangle=90, legend=False)
plt.title('Distribution of Applicants by Job Portal')
plt.ylabel('')  # Hide the y-label
plt.tight_layout()
plt.show()
# Out:
# Job Portal
# Indeed        1728195
# LinkedIn      1665690
# Naukri.com    1740581
# Name: Number of Applicants, dtype: int64

# %% [markdown]
# # Which job titles receive the most applications?

# %%
#Group the data with job title and number of applicants 
jobtitle_applicants=df.groupby('Job Title')['Number of Applicants'].sum()
# Display the result of grouping
print(jobtitle_applicants)
# Out:
# Job Title
# Business Analyst          516921
# Cyber Security Analyst    526471
# Data Scientist            504324
# Financial Analyst         519232
# Graphic Designer          519718
# HR Manager                514049
# Marketing Executive       524063
# Product Manager           513424
# Sales Representative      494002
# Software Engineer         502262
# Name: Number of Applicants, dtype: int64

# %%
# Bar Plot
plt.figure(figsize=(12, 6))
jobtitle_applicants.plot(kind='bar', color='skyblue', edgecolor='black')
plt.title('Number of Applicants by Job Title')
plt.xlabel('Job Title')
plt.ylabel('Number of Applicants')
plt.xticks(rotation=45, ha='right')  # Rotate job titles for better readability
plt.tight_layout()
plt.show()

# %%
# Histogram
plt.figure(figsize=(10, 6))
plt.hist(jobtitle_applicants, bins=10, color='skyblue', edgecolor='black')  # Histogram with bins
plt.title('Histogram of Number of Applicants by Job Title')
plt.xlabel('Number of Applicants')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# %%
# Plotting the pie chart
plt.figure(figsize=(8, 8))
jobtitle_applicants.plot(kind='pie', autopct='%1.1f%%', startangle=90, legend=False)
plt.title('Distribution of Applicants by Job Title')
plt.ylabel('')  # Hide the y-label
plt.tight_layout()
plt.show()

# %% [markdown]
# # Company Analysis:

# %% [markdown]
# # What is the distribution of job postings by company size?

# %%
import matplotlib.pyplot as plt

# Grouping the data by 'Company Size' and counting the number of job postings
company_size_distribution = df.groupby('Company Size').size()

# Display the result of the grouping
print(company_size_distribution)

# Plotting the distribution as a bar plot
plt.figure(figsize=(10, 6))
company_size_distribution.plot(kind='bar', color='skyblue', edgecolor='black')
plt.title('Distribution of Job Postings by Company Size')
plt.xlabel('Company Size')
plt.ylabel('Number of Job Postings')
plt.xticks(rotation=45, ha='right')  # Rotate the company sizes for better readability
plt.tight_layout()
plt.show()
# Out:
# Company Size
# Large (500+)       6638
# Medium (51-500)    6644
# Small (1-50)       6718
# dtype: int64

# %%
# Plotting the distribution as a pie chart
plt.figure(figsize=(8, 8))
company_size_distribution.plot(kind='pie', autopct='%1.1f%%', startangle=90, wedgeprops={'width': 0.3})
plt.title('Distribution of Job Postings by Company Size')
plt.ylabel('')  # Hide the y-label
plt.tight_layout()
plt.show()

# %% [markdown]
# # Which companies offer the most remote work opportunities?

# %%
df
# Out:
#          Job ID             Job Title Company Name Job Location    Job Type  \
# 0          JOB1     Software Engineer       Amazon    Ahmedabad   Full-time
# 1          JOB2   Marketing Executive      Infosys    Ahmedabad  Internship
# 2          JOB3     Financial Analyst     Deloitte       Jaipur    Contract
# 3          JOB4      Business Analyst       Amazon        Delhi   Full-time
# 4          JOB5     Software Engineer      Infosys        Delhi   Full-time
# ...         ...                   ...          ...          ...         ...
# 19995  JOB19996   Marketing Executive     Deloitte         Pune   Full-time
# 19996  JOB19997      Business Analyst    Accenture    Bangalore  Internship
# 19997  JOB19998      Graphic Designer        Wipro       Jaipur   Part-time
# 19998  JOB19999  Sales Representative      Infosys      Kolkata  Internship
# 19999  JOB20000      Business Analyst    Accenture       Mumbai   Part-time
#
# ...

# %%
import matplotlib.pyplot as plt

# Filter the data for remote job postings
remote_jobs = df[df['Remote/Onsite'] == 'Remote']

# Display the filtered 'Company Name' for remote jobs
remote_companies = remote_jobs['Company Name']
print("Companies offering remote jobs:")
print(remote_companies)

# Group by 'Company Name' and count the number of remote jobs per company
remote_jobs_count = remote_jobs.groupby('Company Name').size()

# Display the result sorted by the number of remote job postings
print("\nCount of remote job postings by company:")
print(remote_jobs_count.sort_values(ascending=False))

# Plotting the distribution of remote jobs per company (top 10 companies)
plt.figure(figsize=(12, 6))
remote_jobs_count.sort_values(ascending=False).head(10).plot(kind='bar', color='skyblue', edgecolor='black')
plt.title('Top 10 Companies Offering Remote Work Opportunities')
plt.xlabel('Company Name')
plt.ylabel('Number of Remote Job Postings')
plt.xticks(rotation=45, ha='right')  # Rotate company names for better readability
plt.tight_layout()
plt.show()
# Out:
# Companies offering remote jobs:
# 0           Amazon
# 1          Infosys
# 2         Deloitte
# 5            Wipro
# 9        Microsoft
#            ...
# 19986          HCL
# 19988    Microsoft
# 19994    Accenture
# 19995     Deloitte
# 19999    Accenture
# Name: Company Name, Length: 6742, dtype: object
#
# Count of remote job postings by company:
# Company Name
# Infosys      704
# Microsoft    692
# Wipro        690
# Google       689
# Amazon       687
# Deloitte     681
# IBM          677
# Accenture    655
# HCL          648
# TCS          619
# dtype: int64

# %%
import matplotlib.pyplot as plt

# Plotting the histogram of the number of remote job postings across companies
plt.figure(figsize=(10, 6))
plt.hist(remote_jobs_count, bins=10, color='skyblue', edgecolor='black')  # Adjust the number of bins as needed
plt.title('Distribution of Remote Job Postings Across Companies')
plt.xlabel('Number of Remote Job Postings')
plt.ylabel('Frequency (Number of Companies)')
plt.tight_layout()
plt.show()

# %%
# Plotting the pie chart of remote job postings by company
plt.figure(figsize=(8, 8))
remote_jobs_count.sort_values(ascending=False).head(10).plot(kind='pie', autopct='%1.1f%%', startangle=90, wedgeprops={'width': 0.3})
plt.title('Top 10 Companies Offering Remote Work Opportunities')
plt.ylabel('')  # Hide the y-label
plt.tight_layout()
plt.show()
